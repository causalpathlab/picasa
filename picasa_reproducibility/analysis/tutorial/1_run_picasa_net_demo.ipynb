# %% [markdown]
# # Quick tutorial for `PICASA` training and results analysis using simulated dataset.

# %%
import picasa
import anndata as an
import glob
import os

import matplotlib.pylab as plt
import scanpy as sc


import warnings
warnings.simplefilter(action='ignore', category=UserWarning)
# Out:
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %% [markdown]
# Here, we will use simulated cancer patient data from two patients. The dataset is generated using `splatter`.
#
# First, lets read the simulated cancer patient data from two diffrent patients from `data` directory as anndata objects.

# %%
sample = 'sim'

wdir = os.getcwd()
ddir = wdir +'/data/'

pattern = sample+'_*.h5ad'

# %%
file_paths = glob.glob(os.path.join(ddir, pattern))
file_names = [os.path.basename(file_path) for file_path in file_paths]

batch_map = {}
batch_count = 0
for file_name in file_names:
	print(file_name)
	batch_map[file_name.replace('.h5ad','').replace(sample+'_','')] = an.read_h5ad(ddir+file_name)
	batch_count += 1
# Out:
# sim_patient1.h5ad
# sim_patient2.h5ad

# %% [markdown]
# Create picasa object and link the data.
#
# Here, pairing mode is sequential (default) and neighbour search method is approximate using `Annoy`.

# %%
picasa_object = picasa.create_picasa_object(
	batch_map,
    sample,
	wdir
 	)

picasa_object
# Out:
# Batch pair mode is - seq

# %% [markdown]
# Setup parameters for common net of `PICASA`.

# %%
common_epochs = 1
common_meta_epoch = 5

params = {'device' : 'cuda',
		'batch_size' : 100,
		'input_dim' : 1000,
		'embedding_dim' : 1000,
		'attention_dim' : 15,
		'latent_dim' : 15,
		'encoder_layers' : [100,15],
		'projection_layers' : [25,25],
		'learning_rate' : 0.001,
		'pair_search_method' : 'approx_50',
        'pair_importance_weight': 0.1,
	 	'corruption_tol' : 10.0,
        'cl_loss_mode' : 'none', 
		'epochs': common_epochs,
		'meta_epochs': common_meta_epoch
		}

# %% [markdown]
# Run `PICASA` training -
# First, estimate neighbour pair for each cell in the dataset, and then train the model.

# %%
picasa_object.estimate_neighbour(params['pair_search_method'])
picasa_object.set_nn_params(params)
picasa_object.train_common()
picasa_object.plot_loss(tag='common')
# Out:
# Pair search method - approx_50
# Generating neighbour using approximate method - ANNOY...
# patient1_((3000, 1000)) >patient2_((2900, 1000))
# Generating neighbour using approximate method - ANNOY...
# patient2_((2900, 1000)) >patient1_((3000, 1000))
# Pair search estimate is complete.
# Starting PICASA common training...
# {'device': 'cuda', 'batch_size': 100, 'input_dim': 1000, 'embedding_dim': 1000, 'attention_dim': 15, 'latent_dim': 15, 'encoder_layers': [100, 15], 'projection_layers': [25, 25], 'learning_rate': 0.001, 'pair_search_method': 'approx_50', 'pair_importance_weight': 0.1, 'corruption_tol': 10.0, 'cl_loss_mode': 'none', 'epochs': 1, 'meta_epochs': 5}
# PICASACommonNet(
#   (embedding): GeneEmbedor(
#     (embedding): Embedding(1000, 15)
#     (emb_norm): LayerNorm((15,), eps=1e-05, elementwise_affine=True)
#   )
#   (attention): ScaledDotAttention()
#   (pooling): AttentionPooling()
#   (encoder): ENCODER(
#     (fc): Stacklayers(
#       (layers): ModuleList(
#         (0): Linear(in_features=1000, out_features=100, bias=True)
#         (1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.1, inplace=False)
#         (4): Linear(in_features=100, out_features=15, bias=True)
#         (5): BatchNorm1d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (projector_cl): MLP(
#     (fc): Stacklayers(
#       (layers): ModuleList(
#         (0): Linear(in_features=15, out_features=25, bias=True)
#         (1): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.1, inplace=False)
#         (4): Linear(in_features=25, out_features=25, bias=True)
#         (5): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
# )
# meta_epochs : 1/5
# Training pair - patient1_patient2
# ====> Epoch: 1 Average loss: 5.2790
# Training pair switch - patient2_patient1
# ====> Epoch: 1 Average loss: 5.1601
# Training pair - patient2_patient1
# ====> Epoch: 1 Average loss: 4.9409
# Training pair switch - patient1_patient2
# ====> Epoch: 1 Average loss: 4.8535
# meta_epochs : 2/5
# Training pair - patient1_patient2
# ====> Epoch: 1 Average loss: 4.7782
# Training pair switch - patient2_patient1
# ====> Epoch: 1 Average loss: 4.7316
# Training pair - patient2_patient1
# ====> Epoch: 1 Average loss: 4.7103
# Training pair switch - patient1_patient2
# ====> Epoch: 1 Average loss: 4.6910
# meta_epochs : 3/5
# Training pair - patient1_patient2
# ====> Epoch: 1 Average loss: 4.6777
# Training pair switch - patient2_patient1
# ====> Epoch: 1 Average loss: 4.6748
# Training pair - patient2_patient1
# ====> Epoch: 1 Average loss: 4.6739
# Training pair switch - patient1_patient2
# ====> Epoch: 1 Average loss: 4.6698
# meta_epochs : 4/5
# Training pair - patient1_patient2
# ====> Epoch: 1 Average loss: 4.6686
# Training pair switch - patient2_patient1
# ====> Epoch: 1 Average loss: 4.6720
# Training pair - patient2_patient1
# ====> Epoch: 1 Average loss: 4.6750
# Training pair switch - patient1_patient2
# ====> Epoch: 1 Average loss: 4.6651
# meta_epochs : 5/5
# Training pair - patient1_patient2
# ====> Epoch: 1 Average loss: 4.6665
# Training pair switch - patient2_patient1
# ====> Epoch: 1 Average loss: 4.6691
# Training pair - patient2_patient1
# ====> Epoch: 1 Average loss: 4.6685
# Training pair switch - patient1_patient2
# ====> Epoch: 1 Average loss: 4.6688
# Completed training...model saved in /home/BCCRC.CA/ssubedi/projects/experiments/picasa/picasa_reproducibility/analysis/tutorial/results/picasa_common.model

# %% [markdown]
# Once training is completed, the following files are generated in the results directory -
#
# - picasa_common_train_loss.txt.gz
# - picasa_common_train_loss.png
#
# - Common net model file - picasa_common.model
#
# Next, run inference to generate common latent space for all cells in the dataset.

# %%
device = 'cpu'
picasa_object.nn_params['device'] = device
eval_batch_size = 500
picasa_object.eval_common(eval_batch_size,device)
# Out:
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/picasa/picasa.py:265: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# eval :patient1_patient2
# eval :patient2_patient1

# %% [markdown]
# Next, train unique and base net model for entire dataset without variable gene selection.

# %%
adata_combined = an.concat(picasa_object.data.adata_list, axis=0, join="outer")
adata_combined
# Out:
# AnnData object with n_obs × n_vars = 5900 × 1000
#     obs: 'celltype', 'batch'

# %% [markdown]
# Setup for unique net model.

# %%
unique_epoch = 250
base_epoch = 250

input_dim = picasa_object.data.adata_list[picasa_object.adata_keys[0]].X.shape[1]
enc_layers = [128,15]
unique_latent_dim = 15
common_latent_dim = picasa_object.result.obsm['common'].shape[1]
dec_layers = [128,128]

# %% [markdown]
# Training for unique net model.
#
# Then, run inference to generate unique latent space for all cells in the dataset.

# %%
picasa_object.train_unique(adata_combined, enc_layers,common_latent_dim,unique_latent_dim,dec_layers,l_rate=0.001,epochs=unique_epoch,batch_size=128,device='cuda')
picasa_object.plot_loss(tag='unq')
eval_batch_size = 10
picasa_object.eval_unique(adata_combined, enc_layers,common_latent_dim,unique_latent_dim,dec_layers,eval_batch_size,device='cuda')
# Out:
# PICASAUniqueNet(
#   (u_encoder): MLP(
#     (fc): Stacklayers(
#       (layers): ModuleList(
#         (0): Linear(in_features=1000, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.1, inplace=False)
#         (4): Linear(in_features=128, out_features=15, bias=True)
#         (5): BatchNorm1d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (u_decoder): MLP(
#     (fc): Stacklayers(
#       (layers): ModuleList(
#         (0): Linear(in_features=30, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.1, inplace=False)
#         (4): Linear(in_features=128, out_features=128, bias=True)
#         (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (zinb_scale): Linear(in_features=128, out_features=1000, bias=True)
#   (zinb_dropout): Linear(in_features=128, out_features=1000, bias=True)
#   (batch_discriminator): Linear(in_features=15, out_features=2, bias=True)
# )
# Creating dataloader for training PICASA unique model.
# Training... PICASE unique model.
# ====> Epoch: 0 Average loss: 1257.0936
# ====> Epoch: 10 Average loss: 964.8452
# ====> Epoch: 20 Average loss: 910.4597
# ====> Epoch: 30 Average loss: 870.9267
# ====> Epoch: 40 Average loss: 841.1781
# ====> Epoch: 50 Average loss: 819.1198
# ====> Epoch: 60 Average loss: 802.1423
# ====> Epoch: 70 Average loss: 789.0384
# ====> Epoch: 80 Average loss: 779.2230
# ====> Epoch: 90 Average loss: 771.4095
# ====> Epoch: 100 Average loss: 765.5521
# ====> Epoch: 110 Average loss: 760.6812
# ====> Epoch: 120 Average loss: 756.7449
# ====> Epoch: 130 Average loss: 753.6050
# ====> Epoch: 140 Average loss: 751.2367
# ====> Epoch: 150 Average loss: 749.2876
# ====> Epoch: 160 Average loss: 747.4220
# ====> Epoch: 170 Average loss: 746.2559
# ====> Epoch: 180 Average loss: 745.3207
# ====> Epoch: 190 Average loss: 744.4906
# ====> Epoch: 200 Average loss: 743.4150
# ====> Epoch: 210 Average loss: 742.9610
# ====> Epoch: 220 Average loss: 742.4893
# ====> Epoch: 230 Average loss: 742.1227
# ====> Epoch: 240 Average loss: 741.6528
# Completed training...model saved in /home/BCCRC.CA/ssubedi/projects/experiments/picasa/picasa_reproducibility/analysis/tutorial/results/picasa_unique.model
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/picasa/picasa.py:373: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Creating dataloader for evaluating PICASA unique model.

# %% [markdown]
# Once unique net training is completed, the following files are generated in the results directory -
#
# - picasa_unique_train_loss.txt.gz
# - picasa_unique_train_loss.png
#
# - Unique net model file - picasa_unique.model

# %% [markdown]
# Run base net model to estimate base latent space (no decomposition into common and unique) for all cells in the dataset.

# %%
latent_dim=picasa_object.result.obsm['common'].shape[1]
picasa_object.train_base(adata_combined, enc_layers,latent_dim,dec_layers,l_rate=0.001,epochs=base_epoch,batch_size=128,device='cuda')
picasa_object.plot_loss(tag='base')
eval_batch_size = 10
picasa_object.eval_base(adata_combined, enc_layers,latent_dim,dec_layers,eval_batch_size,device='cuda')
# Out:
# PICASABaseNet(
#   (u_encoder): MLP(
#     (fc): Stacklayers(
#       (layers): ModuleList(
#         (0): Linear(in_features=1000, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.1, inplace=False)
#         (4): Linear(in_features=128, out_features=15, bias=True)
#         (5): BatchNorm1d(15, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (u_decoder): MLP(
#     (fc): Stacklayers(
#       (layers): ModuleList(
#         (0): Linear(in_features=15, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.1, inplace=False)
#         (4): Linear(in_features=128, out_features=128, bias=True)
#         (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU()
#         (7): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (zinb_scale): Linear(in_features=128, out_features=1000, bias=True)
#   (zinb_dropout): Linear(in_features=128, out_features=1000, bias=True)
#   (batch_discriminator): Linear(in_features=15, out_features=2, bias=True)
# )
# Creating dataloader for training PICASA base model.
# Training... PICASE base model.
# ====> Epoch: 0 Average loss: 1242.1732
# ====> Epoch: 10 Average loss: 952.9188
# ====> Epoch: 20 Average loss: 899.2815
# ====> Epoch: 30 Average loss: 862.0857
# ====> Epoch: 40 Average loss: 834.1956
# ====> Epoch: 50 Average loss: 813.5227
# ====> Epoch: 60 Average loss: 798.0534
# ====> Epoch: 70 Average loss: 786.3500
# ====> Epoch: 80 Average loss: 777.2464
# ====> Epoch: 90 Average loss: 770.0042
# ====> Epoch: 100 Average loss: 764.6457
# ====> Epoch: 110 Average loss: 760.4532
# ====> Epoch: 120 Average loss: 756.8137
# ====> Epoch: 130 Average loss: 754.1629
# ====> Epoch: 140 Average loss: 751.8015
# ====> Epoch: 150 Average loss: 750.1665
# ====> Epoch: 160 Average loss: 748.6415
# ====> Epoch: 170 Average loss: 747.3134
# ====> Epoch: 180 Average loss: 746.3733
# ====> Epoch: 190 Average loss: 745.6047
# ====> Epoch: 200 Average loss: 745.1378
# ====> Epoch: 210 Average loss: 744.2123
# ====> Epoch: 220 Average loss: 743.9255
# ====> Epoch: 230 Average loss: 743.3313
# ====> Epoch: 240 Average loss: 743.1946
# Completed training...model saved in /home/BCCRC.CA/ssubedi/projects/experiments/picasa/picasa_reproducibility/analysis/tutorial/results/picasa_base.model
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/picasa/picasa.py:475: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Creating dataloader for evaluating PICASA base model.

# %% [markdown]
# Once base net training is completed, the following files are generated in the results directory -
#
# - picasa_base_train_loss.txt.gz
# - picasa_base_train_loss.png
#
# - Base net model file - picasa_base.model

# %%
picasa_object.save_model()
# Out:
# ... storing 'batch' as categorical

# %% [markdown]
# The following results file is saved with all results including common, unique, and base latent space representation of all cell in the dataset.
# - picasa.h5ad

# %%
picasa_adata = an.read_h5ad(wdir+'/results/picasa.h5ad')

# %% [markdown]
# # Common representation

# %%
sc.pp.neighbors(picasa_adata,use_rep='common')
sc.tl.umap(picasa_adata)
sc.pl.umap(picasa_adata,color=['batch','celltype'])
plt.tight_layout()
# Out:
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1217: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1217: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning

# %% [markdown]
# # Unique representation

# %%
sc.pp.neighbors(picasa_adata,use_rep='unique')
sc.tl.umap(picasa_adata)
sc.pl.umap(picasa_adata,color=['batch','celltype'])
plt.tight_layout()
# Out:
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1217: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1217: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning

# %% [markdown]
# # Base representation

# %%
sc.pp.neighbors(picasa_adata,use_rep='base')
sc.tl.umap(picasa_adata)
sc.pl.umap(picasa_adata,color=['batch','celltype'])
plt.tight_layout()
# Out:
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1217: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
# /home/BCCRC.CA/ssubedi/miniconda3/envs/ssubedi/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1217: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
